# %%
import pandas as pd
import numpy as np
import os, sys

# %%
fn_list_old = sorted(os.listdir(r'/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/'))
fn_list_old= ['HeLa_Acetyl_vs_AbCorr.txt',
 'HeLa_Acetyl_vs_AbCorr_UPK.txt',
 'HeLa_Acetyl_vs_Genome.txt',
 'HeLa_Acetyl_vs_Genome_UPK.txt',
 'HeLa_Acetyl_vs_Observed.txt',
 'HeLa_Acetyl_vs_Observed_UPK.txt',
 'HeLa_Phos_vs_AbCorr.txt',
 'HeLa_Phos_vs_AbCorr_UPK.txt',
 'HeLa_Phos_vs_Genome.txt',
 'HeLa_Phos_vs_Genome_UPK.txt',
 'HeLa_Phos_vs_Observed.txt',
 'HeLa_Phos_vs_Observed_UPK.txt',
 'HeLa_Succinyl_vs_AbCorr.txt',
 'HeLa_Succinyl_vs_AbCorr_UPK.txt',
 'HeLa_Succinyl_vs_Genome.txt',
 'HeLa_Succinyl_vs_Genome_UPK.txt',
 'HeLa_Succinyl_vs_Observed.txt',
 'HeLa_Succinyl_vs_Observed_UPK.txt',
 'HeLa_Ubi_vs_AbCorr.txt',
 'HeLa_Ubi_vs_AbCorr_UPK.txt',
 'HeLa_Ubi_vs_Genome.txt',
 'HeLa_Ubi_vs_Genome_UPK.txt',
 'HeLa_Ubi_vs_Observed.txt',
 'HeLa_Ubi_vs_Observed_UPK.txt',
 'Yeast_Acetyl_vs_AbCorr.txt',
 'Yeast_Acetyl_vs_AbCorr_UPK.txt',
 'Yeast_Acetyl_vs_Genome.txt',
 'Yeast_Acetyl_vs_Genome_UPK.txt',
 'Yeast_Acetyl_vs_Observed.txt',
 'Yeast_Acetyl_vs_Observed_UPK.txt',
 'Yeast_Phos_vs_AbCorr.txt',
 'Yeast_Phos_vs_AbCorr_UPK.txt',
 'Yeast_Phos_vs_Genome.txt',
 'Yeast_Phos_vs_Genome_UPK.txt',
 'Yeast_Phos_vs_Observed.txt',
 'Yeast_Phos_vs_Observed_UPK.txt',
 'Yeast_Succinyl_vs_AbCorr.txt',
 'Yeast_Succinyl_vs_AbCorr_UPK.txt',
 'Yeast_Succinyl_vs_Genome.txt',
 'Yeast_Succinyl_vs_Genome_UPK.txt',
 'Yeast_Succinyl_vs_Observed.txt',
 'Yeast_Succinyl_vs_Observed_UPK.txt',
 'Yeast_Ubi_vs_AbCorr.txt',
 'Yeast_Ubi_vs_AbCorr_UPK.txt',
 'Yeast_Ubi_vs_Genome.txt',
 'Yeast_Ubi_vs_Genome_UPK.txt',
 'Yeast_Ubi_vs_Observed.txt',
 'Yeast_Ubi_vs_Observed_UPK.txt']
print len(fn_list_old)
# Out:
# 48

# %%
# fn_list_new = sorted(os.listdir(r'/Users/dblyon/Downloads/Brian_GO_UPK/v4/'))
# print len(fn_list_new)
fn_list_new = ['HeLa_Acetyl_vs_AbCorr.txt',
 'HeLa_Acetyl_vs_AbCorr_UPK.txt',
 'HeLa_Acetyl_vs_Genome.txt',
 'HeLa_Acetyl_vs_Genome_UPK.txt',
 'HeLa_Acetyl_vs_Observed.txt',
 'HeLa_Acetyl_vs_Observed_UPK.txt',
 'HeLa_Phos_vs_AbCorr.txt',
 'HeLa_Phos_vs_AbCorr_UPK.txt',
 'HeLa_Phos_vs_Genome.txt',
 'HeLa_Phos_vs_Genome_UPK.txt',
 'HeLa_Phos_vs_Observed.txt',
 'HeLa_Phos_vs_Observed_UPK.txt',
 'HeLa_Succinyl_vs_AbCorr.txt',
 'HeLa_Succinyl_vs_AbCorr_UPK.txt',
 'HeLa_Succinyl_vs_Genome.txt',
 'HeLa_Succinyl_vs_Genome_UPK.txt',
 'HeLa_Succinyl_vs_Observed.txt',
 'HeLa_Succinyl_vs_Observed_UPK.txt',
 'HeLa_Ubi_vs_AbCorr.txt',
 'HeLa_Ubi_vs_AbCorr_UPK.txt',
 'HeLa_Ubi_vs_Genome.txt',
 'HeLa_Ubi_vs_Genome_UPK.txt',
 'HeLa_Ubi_vs_Observed.txt',
 'HeLa_Ubi_vs_Observed_UPK.txt',
 'Yeast_Acetyl_vs_AbCorr.txt',
 'Yeast_Acetyl_vs_AbCorr_UPK.txt',
 'Yeast_Acetyl_vs_Genome.txt',
 'Yeast_Acetyl_vs_Genome_UPK.txt',
 'Yeast_Acetyl_vs_Observed.txt',
 'Yeast_Acetyl_vs_Observed_UPK.txt',
 'Yeast_Phos_vs_AbCorr.txt',
 'Yeast_Phos_vs_AbCorr_UPK.txt',
 'Yeast_Phos_vs_Genome.txt',
 'Yeast_Phos_vs_Genome_UPK.txt',
 'Yeast_Phos_vs_Observed.txt',
 'Yeast_Phos_vs_Observed_UPK.txt',
 'Yeast_Succinyl_vs_AbCorr.txt',
 'Yeast_Succinyl_vs_AbCorr_UPK.txt',
 'Yeast_Succinyl_vs_Genome.txt',
 'Yeast_Succinyl_vs_Genome_UPK.txt',
 'Yeast_Succinyl_vs_Observed.txt',
 'Yeast_Succinyl_vs_Observed_UPK.txt',
 'Yeast_Ubi_vs_AbCorr.txt',
 'Yeast_Ubi_vs_AbCorr_UPK.txt',
 'Yeast_Ubi_vs_Genome.txt',
 'Yeast_Ubi_vs_Genome_UPK.txt',
 'Yeast_Ubi_vs_Observed.txt',
 'Yeast_Ubi_vs_Observed_UPK.txt']
print len(fn_list_new)
# Out:
# 48

# %%
fn_list_old = [r'/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/'+fn for fn in fn_list_old]
fn_list_new = [r'/Users/dblyon/Downloads/Brian_GO_UPK/v4/'+fn for fn in fn_list_new]

# %%
fn_old2new = zip(fn_list_old, fn_list_new)
fn_old2new
# Out:
# [('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Acetyl_vs_AbCorr.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Acetyl_vs_AbCorr.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Acetyl_vs_AbCorr_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Acetyl_vs_AbCorr_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Acetyl_vs_Genome.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Acetyl_vs_Genome.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Acetyl_vs_Genome_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Acetyl_vs_Genome_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Acetyl_vs_Observed.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Acetyl_vs_Observed.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Acetyl_vs_Observed_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Acetyl_vs_Observed_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Phos_vs_AbCorr.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Phos_vs_AbCorr.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Phos_vs_AbCorr_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Phos_vs_AbCorr_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Phos_vs_Genome.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Phos_vs_Genome.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Phos_vs_Genome_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Phos_vs_Genome_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Phos_vs_Observed.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Phos_vs_Observed.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Phos_vs_Observed_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Phos_vs_Observed_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Succinyl_vs_AbCorr.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Succinyl_vs_AbCorr.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Succinyl_vs_AbCorr_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Succinyl_vs_AbCorr_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Succinyl_vs_Genome.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Succinyl_vs_Genome.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Succinyl_vs_Genome_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Succinyl_vs_Genome_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Succinyl_vs_Observed.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Succinyl_vs_Observed.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Succinyl_vs_Observed_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Succinyl_vs_Observed_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Ubi_vs_AbCorr.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Ubi_vs_AbCorr.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Ubi_vs_AbCorr_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Ubi_vs_AbCorr_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Ubi_vs_Genome.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Ubi_vs_Genome.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Ubi_vs_Genome_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Ubi_vs_Genome_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Ubi_vs_Observed.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Ubi_vs_Observed.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/HeLa_Ubi_vs_Observed_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/HeLa_Ubi_vs_Observed_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Acetyl_vs_AbCorr.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Acetyl_vs_AbCorr.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Acetyl_vs_AbCorr_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Acetyl_vs_AbCorr_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Acetyl_vs_Genome.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Acetyl_vs_Genome.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Acetyl_vs_Genome_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Acetyl_vs_Genome_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Acetyl_vs_Observed.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Acetyl_vs_Observed.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Acetyl_vs_Observed_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Acetyl_vs_Observed_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Phos_vs_AbCorr.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Phos_vs_AbCorr.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Phos_vs_AbCorr_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Phos_vs_AbCorr_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Phos_vs_Genome.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Phos_vs_Genome.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Phos_vs_Genome_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Phos_vs_Genome_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Phos_vs_Observed.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Phos_vs_Observed.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Phos_vs_Observed_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Phos_vs_Observed_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Succinyl_vs_AbCorr.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Succinyl_vs_AbCorr.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Succinyl_vs_AbCorr_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Succinyl_vs_AbCorr_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Succinyl_vs_Genome.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Succinyl_vs_Genome.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Succinyl_vs_Genome_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Succinyl_vs_Genome_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Succinyl_vs_Observed.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Succinyl_vs_Observed.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Succinyl_vs_Observed_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Succinyl_vs_Observed_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Ubi_vs_AbCorr.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Ubi_vs_AbCorr.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Ubi_vs_AbCorr_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Ubi_vs_AbCorr_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Ubi_vs_Genome.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Ubi_vs_Genome.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Ubi_vs_Genome_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Ubi_vs_Genome_UPK.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Ubi_vs_Observed.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Ubi_vs_Observed.txt'),
#  ('/Users/dblyon/Downloads/Brian_GO_UPK/v3/submission/Yeast_Ubi_vs_Observed_UPK.txt',
#   '/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Ubi_vs_Observed_UPK.txt')]

# %%
os.path.basename('/Users/dblyon/Downloads/Brian_GO_UPK/v4/Yeast_Ubi_vs_Observed_UPK.txt')
# Out:
# 'Yeast_Ubi_vs_Observed_UPK.txt'

# %%
for old_new in fn_old2new:
    fn_old, fn_new = old_new
    df_old = pd.read_csv(fn_old, sep='\t')
    df_new = pd.read_csv(fn_new, sep='\t')    
    pop_n_old = df_old['pop_n'].iloc[0]
    study_n_old = df_old['study_n'].iloc[0]
    pop_n_new = df_new['pop_n'].iloc[0]
    study_n_new = df_new['study_n'].iloc[0]

#     if study_n_old == study_n_new:
#         print os.path.basename(fn_old)
# #         print 'study_n old vs new: ', study_n_old, study_n_new
#     if pop_n_old == pop_n_new:
#         print os.path.basename(fn_old)
# #         print 'pop_n old vs new: ', pop_n_old, pop_n_new    
        
    if study_n_old != study_n_new or pop_n_old != pop_n_new:
        print os.path.basename(fn_old)
        print 'study_n old vs new: ', study_n_old, study_n_new
        print 'pop_n old vs new: ', pop_n_old, pop_n_new
        print
# Out:
# HeLa_Acetyl_vs_AbCorr.txt
# study_n old vs new:  1663 1612
# pop_n old vs new:  1663 1612
#
# HeLa_Acetyl_vs_AbCorr_UPK.txt
# study_n old vs new:  1663 1626
# pop_n old vs new:  1663 1626
#
# HeLa_Acetyl_vs_Genome.txt
# study_n old vs new:  1663 1612
# pop_n old vs new:  68562 46672
#
# HeLa_Acetyl_vs_Genome_UPK.txt
# study_n old vs new:  1663 1626
# pop_n old vs new:  68562 68561
#
# HeLa_Acetyl_vs_Observed.txt
# study_n old vs new:  1663 1612
# pop_n old vs new:  6856 6464
#
# HeLa_Acetyl_vs_Observed_UPK.txt
# study_n old vs new:  1663 1626
# pop_n old vs new:  6856 6643
#
# HeLa_Phos_vs_AbCorr.txt
# study_n old vs new:  3158 2992
# pop_n old vs new:  3158 2992
#
# HeLa_Phos_vs_AbCorr_UPK.txt
# study_n old vs new:  3158 3060
# pop_n old vs new:  3158 3060
#
# HeLa_Phos_vs_Genome.txt
# study_n old vs new:  3158 2992
# pop_n old vs new:  68562 46672
#
# HeLa_Phos_vs_Genome_UPK.txt
# study_n old vs new:  3158 3060
# pop_n old vs new:  68562 68561
#
# HeLa_Phos_vs_Observed.txt
# study_n old vs new:  3158 2992
# pop_n old vs new:  6856 6464
#
# HeLa_Phos_vs_Observed_UPK.txt
# study_n old vs new:  3158 3060
# pop_n old vs new:  6856 6643
#
# HeLa_Succinyl_vs_AbCorr.txt
# study_n old vs new:  790 775
# pop_n old vs new:  790 775
#
# HeLa_Succinyl_vs_AbCorr_UPK.txt
# study_n old vs new:  790 778
# pop_n old vs new:  790 778
#
# HeLa_Succinyl_vs_Genome.txt
# study_n old vs new:  790 775
# pop_n old vs new:  68562 46672
#
# HeLa_Succinyl_vs_Genome_UPK.txt
# study_n old vs new:  790 778
# pop_n old vs new:  68562 68561
#
# HeLa_Succinyl_vs_Observed.txt
# study_n old vs new:  790 775
# pop_n old vs new:  6856 6464
#
# HeLa_Succinyl_vs_Observed_UPK.txt
# study_n old vs new:  790 778
# pop_n old vs new:  6856 6643
#
# HeLa_Ubi_vs_AbCorr.txt
# study_n old vs new:  2312 2226
# pop_n old vs new:  2312 2226
#
# HeLa_Ubi_vs_AbCorr_UPK.txt
# study_n old vs new:  2312 2253
# pop_n old vs new:  2312 2253
#
# HeLa_Ubi_vs_Genome.txt
# study_n old vs new:  2312 2226
# pop_n old vs new:  68562 46672
#
# HeLa_Ubi_vs_Genome_UPK.txt
# study_n old vs new:  2312 2253
# pop_n old vs new:  68562 68561
#
# HeLa_Ubi_vs_Observed.txt
# study_n old vs new:  2312 2226
# pop_n old vs new:  6856 6464
#
# HeLa_Ubi_vs_Observed_UPK.txt
# study_n old vs new:  2312 2253
# pop_n old vs new:  6856 6643
#
# Yeast_Acetyl_vs_AbCorr.txt
# study_n old vs new:  1125 1123
# pop_n old vs new:  1125 1123
#
# Yeast_Acetyl_vs_AbCorr_UPK.txt
# study_n old vs new:  1125 1123
# pop_n old vs new:  1125 1123
#
# Yeast_Acetyl_vs_Genome.txt
# study_n old vs new:  1125 1123
# pop_n old vs new:  6722 5912
#
# Yeast_Acetyl_vs_Genome_UPK.txt
# study_n old vs new:  1125 1123
# pop_n old vs new:  6722 6721
#
# Yeast_Acetyl_vs_Observed.txt
# study_n old vs new:  1125 1123
# pop_n old vs new:  4249 4242
#
# Yeast_Acetyl_vs_Observed_UPK.txt
# study_n old vs new:  1125 1123
# pop_n old vs new:  4249 4246
#
# Yeast_Phos_vs_Genome.txt
# study_n old vs new:  1552 1552
# pop_n old vs new:  6721 5912
#
# Yeast_Phos_vs_Observed.txt
# study_n old vs new:  1552 1552
# pop_n old vs new:  4249 4242
#
# Yeast_Phos_vs_Observed_UPK.txt
# study_n old vs new:  1552 1552
# pop_n old vs new:  4249 4246
#
# Yeast_Succinyl_vs_AbCorr.txt
# study_n old vs new:  631 629
# pop_n old vs new:  631 629
#
# Yeast_Succinyl_vs_AbCorr_UPK.txt
# study_n old vs new:  631 629
# pop_n old vs new:  631 629
#
# Yeast_Succinyl_vs_Genome.txt
# study_n old vs new:  631 629
# pop_n old vs new:  6722 5912
#
# Yeast_Succinyl_vs_Genome_UPK.txt
# study_n old vs new:  631 629
# pop_n old vs new:  6722 6721
#
# Yeast_Succinyl_vs_Observed.txt
# study_n old vs new:  631 629
# pop_n old vs new:  4249 4242
#
# Yeast_Succinyl_vs_Observed_UPK.txt
# study_n old vs new:  631 629
# pop_n old vs new:  4249 4246
#
# Yeast_Ubi_vs_AbCorr.txt
# study_n old vs new:  1087 1086
# pop_n old vs new:  1087 1086
#
# Yeast_Ubi_vs_AbCorr_UPK.txt
# study_n old vs new:  1087 1086
# pop_n old vs new:  1087 1086
#
# Yeast_Ubi_vs_Genome.txt
# study_n old vs new:  1087 1086
# pop_n old vs new:  6722 5912
#
# Yeast_Ubi_vs_Genome_UPK.txt
# study_n old vs new:  1087 1086
# pop_n old vs new:  6722 6721
#
# Yeast_Ubi_vs_Observed.txt
# study_n old vs new:  1087 1086
# pop_n old vs new:  4249 4242
#
# Yeast_Ubi_vs_Observed_UPK.txt
# study_n old vs new:  1087 1086
# pop_n old vs new:  4249 4246
