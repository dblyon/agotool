# %%
import fisher
from scipy import stats

# %% [markdown]
# # CORRECT FISHER EXACT TEST

# %%
##### CORRECT R example
a = 2
b = 15
c = 10
d = 3

col_1 = a + b
r1 = a + c
n = a + b + c + d

print scipy.stats.fisher_exact([[a, b], [c, d]], alternative='two-sided')
print fisher.pvalue(a, b, c, d)
print fisher.pvalue_population(a, col_1, r1, n)
#       Group1    Group2
# pos     A         C       r1
# neg     B         D       r2
#        col_1     col_2    n

#             Convicted Not convicted
# Dizygotic           2            15
# Monozygotic        10             3
# Convictions <- matrix(c(2, 10, 15, 3), nrow = 2,
#          dimnames =
#            list(c("Dizygotic", "Monozygotic"),
#                 c("Convicted", "Not convicted")))
# Convictions
# fisher.test(Convictions, alternative = "two.sided")
# fisher.test(Convictions, alternative="less")
# Out:
# (0.040000000000000001, 0.00053672411914343723)
# Pvalue(left_tail=0.0004652, right_tail=1, two_tail=0.0005367)
# Pvalue(left_tail=0.0004652, right_tail=1, two_tail=0.0005367)

# %%
# CORRECT Wikipedia example
a = 0
b = 12
c = 10
d = 2

col_1 = a + b
r1 = a + c
n = a + b + c + d

print scipy.stats.fisher_exact([[a, b], [c, d]], alternative='two-sided')
print fisher.pvalue(a, b, c, d)
print fisher.pvalue_population(a, col_1, r1, n)
# fisher.test(rbind(c(0,10),c(12,2)), alternative="two.sided")$p.value
# fisher.test(rbind(c(a, c),c(b, d)), alternative="two.sided")$p.value
#       Group1    Group2
# pos     A         C       r1
# neg     B         D       r2
#        col_1     col_2    n

#             Men            Women
# Dieting      0              10
# Non-diet    12               2
# Out:
# (0.0, 6.7303809395611843e-05)
# Pvalue(left_tail=3.365e-05, right_tail=1, two_tail=6.73e-05)
# Pvalue(left_tail=3.365e-05, right_tail=1, two_tail=6.73e-05)

# %%
# testing david vs. Brian data

# %%
study_count = 1522
study_n = 1663
pop_count = 1472
pop_n = 1663

a = study_count
b = study_n - study_count
c = pop_count
d = pop_n - pop_count

col_1 = a + b
r1 = a + c
n = a + b + c + d
# David 
print scipy.stats.fisher_exact([[a, b], [c, d]], alternative='two-sided')
print fisher.pvalue(a, b, c, d)
print fisher.pvalue_population(a, col_1, r1, n)
print a, b, c, d
# Brian 
print fisher.pvalue(a, col_1, c, col_2) # or something similar
# Out:
# (1.400622494603762, 0.0045326291963543432)
# Pvalue(left_tail=0.9984, right_tail=0.002266, two_tail=0.004533)
# Pvalue(left_tail=0.9984, right_tail=0.002266, two_tail=0.004533)
# 1522 141 1472 191
# Pvalue(left_tail=0.7655, right_tail=0.2503, two_tail=0.4965)

# %%
4249 / 1125.0
# Out:
# 3.7768888888888887

# %% [markdown]
# # proportional p-value

# %%
import pandas as pd
import fisher
directory = r'/Users/dblyon/Downloads/Brian_GO_UPK/v3/'
fn_abcorr = directory + 'Yeast_Acetyl_vs_AbCorr.txt'
fn_obs = directory + 'Yeast_Acetyl_vs_Observed.txt'
df_abcorr = pd.read_csv(fn_abcorr, sep='\t', skiprows=1)
df_abcorr.index = df_abcorr['id'].tolist()
df_obs = pd.read_csv(fn_obs, sep='\t', skiprows=1)
df_obs.index = df_obs['id'].tolist()

# %%
df_at = df_abcorr.iloc[0:10, ]
df_at = df_at[['study_count','study_n','pop_count','pop_n', 'p_uncorrected']]
df_at
# Out:
#                      study_count  study_n  pop_count  pop_n  p_uncorrected
# ....GO:0006284                 7     1125          1   1125         0.0698
# ....GO:0070577                 6     1125          1   1125         0.1240
# .......GO:0061188              6     1125          1   1125         0.1240
# ....GO:0045926                 6     1125          1   1125         0.1240
# .....GO:0005671                6     1125          1   1125         0.1240
# .........GO:0000436            6     1125          1   1125         0.1240
# .....GO:0060258                6     1125          1   1125         0.1240
# ....GO:0001228                11     1125          2   1125         0.0221
# ....GO:0000983                11     1125          2   1125         0.0221
# ......GO:0000124              11     1125          2   1125         0.0221

# %%
df_ot = df_obs.loc[df_at.index, ]
df_ot = df_ot[['study_count','study_n','pop_count','pop_n', 'p_uncorrected']]
df_ot
# Out:
#                      study_count  study_n  pop_count  pop_n  p_uncorrected
# ....GO:0006284                 7     1125         13   4249         0.1620
# ....GO:0070577                 6     1125          7   4249         0.0368
# .......GO:0061188              6     1125          8   4249         0.0904
# ....GO:0045926                 6     1125          8   4249         0.0904
# .....GO:0005671                6     1125          6   4249         0.0240
# .........GO:0000436            6     1125         15   4249         0.4180
# .....GO:0060258                6     1125          8   4249         0.0904
# ....GO:0001228                11     1125         25   4249         0.1530
# ....GO:0000983                11     1125         16   4249         0.0169
# ......GO:0000124              11     1125         20   4249         0.0722

# %%
def add_proportional_p_val(df_abcorr, df_observed):
    '''
    returns df_abcorr with an additional p_uncorrected_prop column
    '''
    # ratio stays the same for two corresponding dataframes
    pop_n_observed = df_observed.iloc[0]['pop_n']
    pop_n_abcorr = df_abcorr.iloc[0]['pop_n']
    ratio = float(pop_n_observed) / pop_n_abcorr
        
    df_abcorr['p_uncorr_prop'] = -1.0
    iterrows = df_abcorr.iterrows()
    for row in iterrows:
        index = row[0]
        
        study_count_abcorr = row[1]['study_count']
        study_n_abcorr = row[1]['study_n']
        pop_n_abcorr = row[1]['pop_n']
        pop_count_abcorr = row[1]['pop_count']        

        pop_n_prop = pop_n_abcorr * ratio
        pop_count_prop = pop_count_abcorr * ratio
        
        a = study_count_abcorr
        b = study_n_abcorr - study_count_abcorr
        c = pop_count_prop
        d = pop_n_prop - pop_count_prop
        p_val_prop = fisher.pvalue(a, b, c, d).two_tail
        df_abcorr.loc[index, 'p_uncorr_prop'] = p_val_prop
    return df_abcorr

# %%
add_proportional_p_val(df_at, df_ot)
# Out:
#                      study_count  study_n  pop_count  pop_n  p_uncorrected  \
# ....GO:0006284                 7     1125          1   1125         0.0698
# ....GO:0070577                 6     1125          1   1125         0.1240
# .......GO:0061188              6     1125          1   1125         0.1240
# ....GO:0045926                 6     1125          1   1125         0.1240
# .....GO:0005671                6     1125          1   1125         0.1240
# .........GO:0000436            6     1125          1   1125         0.1240
# .....GO:0060258                6     1125          1   1125         0.1240
# ....GO:0001228                11     1125          2   1125         0.0221
# ....GO:0000983                11     1125          2   1125         0.0221
# ......GO:0000124              11     1125          2   1125         0.0221
#
#                      p_uncorr_prop
# ....GO:0006284            0.001143
# ....GO:0070577            0.003891
# .......GO:0061188         0.003891
# ....GO:0045926            0.003891
# .....GO:0005671           0.003891
# .........GO:0000436       0.003891
# .....GO:0060258           0.003891
# ....GO:0001228            0.000238
# ....GO:0000983            0.000238
# ......GO:0000124          0.000238

# %%
import os
fn_list = os.listdir(directory)
fn_abcorr_list = []
fn_abcorr_UPK_list = []
for fn in fn_list:
    if fn.endswith("_AbCorr.txt"):
        fn_abcorr_list.append(fn)
    elif fn.endswith("_AbCorr_UPK.txt"):
        fn_abcorr_UPK_list.append(fn)

# %%
fn_pair_list = zip(fn_abcorr_list, [fn.replace('AbCorr', 'Observed') for fn in fn_abcorr_list])
fn_pair_UPK_list = zip(fn_abcorr_UPK_list, [fn.replace('AbCorr', 'Observed') for fn in fn_abcorr_UPK_list])
fn_pair_list += fn_pair_UPK_list
fn_pair_list
# Out:
# [('HeLa_Acetyl_vs_AbCorr.txt', 'HeLa_Acetyl_vs_Observed.txt'),
#  ('HeLa_Phos_vs_AbCorr.txt', 'HeLa_Phos_vs_Observed.txt'),
#  ('HeLa_Succinyl_vs_AbCorr.txt', 'HeLa_Succinyl_vs_Observed.txt'),
#  ('HeLa_Ubi_vs_AbCorr.txt', 'HeLa_Ubi_vs_Observed.txt'),
#  ('Yeast_Acetyl_vs_AbCorr.txt', 'Yeast_Acetyl_vs_Observed.txt'),
#  ('Yeast_Phos_vs_AbCorr.txt', 'Yeast_Phos_vs_Observed.txt'),
#  ('Yeast_Succinyl_vs_AbCorr.txt', 'Yeast_Succinyl_vs_Observed.txt'),
#  ('Yeast_Ubi_vs_AbCorr.txt', 'Yeast_Ubi_vs_Observed.txt'),
#  ('HeLa_Acetyl_vs_AbCorr_UPK.txt', 'HeLa_Acetyl_vs_Observed_UPK.txt'),
#  ('HeLa_Phos_vs_AbCorr_UPK.txt', 'HeLa_Phos_vs_Observed_UPK.txt'),
#  ('HeLa_Succinyl_vs_AbCorr_UPK.txt', 'HeLa_Succinyl_vs_Observed_UPK.txt'),
#  ('HeLa_Ubi_vs_AbCorr_UPK.txt', 'HeLa_Ubi_vs_Observed_UPK.txt'),
#  ('Yeast_Acetyl_vs_AbCorr_UPK.txt', 'Yeast_Acetyl_vs_Observed_UPK.txt'),
#  ('Yeast_Phos_vs_AbCorr_UPK.txt', 'Yeast_Phos_vs_Observed_UPK.txt'),
#  ('Yeast_Succinyl_vs_AbCorr_UPK.txt', 'Yeast_Succinyl_vs_Observed_UPK.txt'),
#  ('Yeast_Ubi_vs_AbCorr_UPK.txt', 'Yeast_Ubi_vs_Observed_UPK.txt')]

# %%
directory = r'/Users/dblyon/Downloads/Brian_GO_UPK/v3/'

for fn_ab__fn_ob in fn_pair_list:
    fn_ab, fn_ob = fn_ab__fn_ob
#     print directory+fn_ob
    df_abcorr = pd.read_csv(directory+fn_ab, sep='\t', skiprows=1)
    df_abcorr.index = df_abcorr['id'].tolist()
    df_obs = pd.read_csv(directory+fn_ob, sep='\t', skiprows=1)
    df_obs.index = df_obs['id'].tolist()
    df_new = add_proportional_p_val(df_abcorr, df_obs)
    fn_out = fn_ab.replace(".txt", "_prop.txt")
    df_new.to_csv(fn_out, sep='\t', index=False, header=True)

# %%
fn= r'/Users/dblyon/Downloads/Brian_GO_UPK/v3/proportional_p_value/Yeast_Acetyl_vs_AbCorr_prop.txt'

# %%
df = pd.read_csv(fn, sep='\t')

# %%
df
# Out:
#                        id enrichment  perc_enrichment_study  \
# 0          ....GO:0006284          e                    0.6
# 1          ....GO:0070577          e                    0.5
# 2       .......GO:0061188          e                    0.5
# 3          ....GO:0045926          e                    0.5
# 4         .....GO:0005671          e                    0.5
# 5     .........GO:0000436          e                    0.5
# 6         .....GO:0060258          e                    0.5
# 7          ....GO:0001228          e                    1.0
# 8          ....GO:0000983          e                    1.0
# 9        ......GO:0000124          e                    1.0
# 10        .....GO:0001077          e                    1.0
# 11        .....GO:0005669          e                    0.9
# 12       ......GO:0046695          e                    0.9
# 13        .....GO:0001075          e                    0.9
# 14      .......GO:0008296          e                    0.4
# 15         ....GO:0001227          e                    0.4
# 16       ......GO:1900429          e                    0.4
# 17       ......GO:0016239          e                    0.4
# 18      .......GO:0010508          e                    0.4
# 19         ....GO:0035064          e                    0.4
# 20       ......GO:2000221          e                    0.4
# 21         ....GO:0000117          e                    0.4
# 22         ....GO:0005985          e                    0.4
# 23        .....GO:0005987          e                    0.4
# 24       ......GO:0072364          e                    0.4
# 25        .....GO:0030308          e                    0.4
# 26        .....GO:0016241          e                    0.4
# 27        .....GO:0001078          e                    0.4
# 28        .....GO:0043137          e                    0.4
# 29           ..GO:0000386          e                    0.4
# ...                   ...        ...                    ...
# 4866      .....GO:0035361          e                    0.1
# 4867      .....GO:0090372          e                    0.1
# 4868       ....GO:0016649          e                    0.1
# 4869  .........GO:0035024          e                    0.1
# 4870     ......GO:1900060          e                    0.1
# 4871      .....GO:0006120          e                    0.1
# 4872     ......GO:0070869          e                    0.1
# 4873     ......GO:0000388          e                    0.1
# 4874  .........GO:2001160          e                    0.1
# 4875      .....GO:0000036          e                    0.1
# 4876      .....GO:0042736          e                    0.1
# 4877      .....GO:0004729          e                    0.1
# 4878     ......GO:0033241          e                    0.1
# 4879   ........GO:1900469          e                    0.1
# 4880        ...GO:0001666          e                    0.1
# 4881       ....GO:0022614          e                    0.1
# 4882  .........GO:0032297          e                    0.1
# 4883        ...GO:0032299          e                    0.1
# 4894                  0.0                       -1.0            1     1125
# 4895                  0.0                       -1.0            1     1125
#
#       pop_count  pop_n                                        description  \
# 0             1   1125                               base-excision repair
# 1             1   1125                  lysine-acetylated histone binding
# 2             1   1125  negative regulation of chromatin silencing at ...
# 3             1   1125                      negative regulation of growth
# 4             1   1125     Ada2/Gcn5/Ada3 transcription activator complex
# 5             1   1125  carbon catabolite activation of transcription ...
# 6             1   1125          negative regulation of filamentous growth
# 7             2   1125  RNA polymerase II transcription regulatory reg...
# 8             2   1125  RNA polymerase II core promoter sequence-speci...
# 9             2   1125                                       SAGA complex
# 10            2   1125  RNA polymerase II core promoter proximal regio...
# 11            2   1125                 transcription factor TFIID complex
# 12            2   1125                           SLIK (SAGA-like) complex
# 13            2   1125  RNA polymerase II core promoter sequence-speci...
# 14            1   1125                3'-5'-exodeoxyribonuclease activity
# 15            1   1125  RNA polymerase II transcription regulatory reg...
# 16            1   1125  negative regulation of filamentous growth of a...
# 17            1   1125              positive regulation of macroautophagy
# 18            1   1125                   positive regulation of autophagy
# 19            1   1125                         methylated histone binding
# 20            1   1125         negative regulation of pseudohyphal growth
# 21            1   1125  regulation of transcription involved in G2/M t...
# 22            1   1125                          sucrose metabolic process
# 23            1   1125                          sucrose catabolic process
# 24            1   1125  regulation of cellular ketone metabolic proces...
# 25            1   1125                 negative regulation of cell growth
# 26            1   1125                       regulation of macroautophagy
# 27            1   1125  RNA polymerase II core promoter proximal regio...
# 28            1   1125             DNA replication, removal of RNA primer
# 29            1   1125   second spliceosomal transesterification activity
# ...         ...    ...                                                ...
# 4866          0   1125                 Cul8-RING ubiquitin ligase complex
# 4867          0   1125          positive regulation of glycerol transport
# 4868          0   1125  oxidoreductase activity, acting on the CH-NH g...
# 4869          0   1125  negative regulation of Rho protein signal tran...
# 4870          0   1125  negative regulation of ceramide biosynthetic p...
# 4871          0   1125  mitochondrial electron transport, NADH to ubiq...
# 4872          0   1125  heterochromatin assembly involved in chromatin...
# 4873          0   1125  spliceosome conformational change to release U...
# 4874          0   1125           regulation of histone H3-K79 methylation
# 4875          0   1125  ACP phosphopantetheine attachment site binding...
# 4876          0   1125                               NADH kinase activity
# 4877          0   1125  oxygen-dependent protoporphyrinogen oxidase ac...
# 4878          0   1125     regulation of cellular amine catabolic process
# 4879          0   1125  negative regulation of phosphatidylserine bios...
# 4880          0   1125                                response to hypoxia
# 4881          0   1125                       membrane to membrane docking
# 4882          0   1125  negative regulation of DNA-dependent DNA repli...
# 4883          0   1125                            ribonuclease H2 complex
# 4884          0   1125                  oligopeptide transporter activity
# 4885          0   1125      tRNA (cytosine-5-)-methyltransferase activity
# 4886          0   1125  2-octaprenyl-6-methoxyphenol hydroxylase activity
# 4887          0   1125  negative regulation of transcription by transc...
# 4888          0   1125  regulation of glutamine family amino acid meta...
# 4889          0   1125               NADPH-adrenodoxin reductase activity
# 7     P12383,P14164,P17106,P25302,P25502,P39678,P404...
# 8     P13393,P23255,P35189,P38129,P38351,P50105,P530...
# 9     P25554,P32494,P32657,P35177,P38129,P53040,P531...
# 10    P12383,P14164,P17106,P25302,P25502,P39678,P404...
# 11    P13393,P23255,P35189,P38129,P50105,P53040,Q037...
# 12    P32494,P32657,P35177,P38129,P53040,P53165,Q023...
# 13    P13393,P23255,P35189,P38129,P50105,P53040,Q037...
# 14                   P15436,P21951,P22936,P46957,P47110
# 15                   P17106,P39001,P39956,P40466,Q03833
# 16                   P20134,P40466,P41813,Q03063,Q03373
# 17                   P17157,P32561,P43572,Q06671,Q08649
# 18                   P17157,P32561,P43572,Q06671,Q08649
# 19                   P25554,P32657,P36124,Q03012,Q08923
# 20                   P20134,P40466,P41813,Q03063,Q03373
# 21                   P22579,P32561,P40466,P41813,Q08887
# 22                   P18480,P18888,P22082,P32591,P38158
# 23                   P18480,P18888,P22082,P32591,P38158
# 24                   P07248,P14922,P16649,P31385,P39001
# 25                   P20134,P40466,P41813,Q03063,Q03373
# 26                   P17157,P32561,P43572,Q06671,Q08649
# 27                   P17106,P39001,P39956,P40466,Q03833
# 28                   P15436,P26793,P46957,P47110,Q05635
# 29                   P24384,P28004,P33411,Q02775,Q12309
# ...                                                 ...
# 4866                                             P38850
# 4867                                             P48361
# 4868                                             Q08822
# 4869                                             P39960
# 4870                                             P17106
# 4871                                             P32340
# 4872                                             P40161
# 4873                                             P32639
# 4874                                             P53064
# 4875                                             P32463
# 4876                                             P21373
# 4877                                             P40012
# 4878                                             P25502
# 4879                                             P31385
# 4880                                             P33417
# 4881                                             P39968
# 4882                                             P09798
# 4883                                             Q05635
# 4884                                             P32901
# 4885                                             P38205
# 4886                                             P53318
# 4887                                             P53973
# 4888                                             P25502
# 4889                                             P48360
# 4890                                             Q06685
# 4891                                             Q06508
# 4892                                             Q04013
# 4893                                             Q05958
# 4894                                             P17442
# 4895                                             P21951
#
#                                                 ANs_pop p_fdr  p_uncorr_prop
# 0     P04819,P12753,P12887,P21951,P22936,P31378,P325...  n.a.       0.001143
# 1      P22082,P32597,P35817,P43583,Q02206,Q03330,Q07442  n.a.       0.003891
# 2     P22579,P31385,P32561,P38255,P38429,P40505,P509...  n.a.       0.003891
# 3     P20134,P38236,P39073,P40466,P41813,Q03063,Q031...  n.a.       0.003891
# 4             P25554,P32494,Q02336,Q03330,Q12060,Q12433  n.a.       0.003891
# 5     P07248,P09547,P13045,P13434,P14064,P18480,P325...  n.a.       0.003891
# 6     P20134,P38236,P39073,P40466,P41813,Q03063,Q031...  n.a.       0.003891
# 7     P08638,P12383,P13434,P14064,P14164,P17106,P248...  n.a.       0.000238
# 8     P13393,P23255,P35189,P38129,P38351,P46677,P501...  n.a.       0.000238
# 9     P06844,P25554,P32494,P32657,P35177,P38129,P388...  n.a.       0.000238
# 10    P08638,P12383,P13434,P14064,P14164,P17106,P248...  n.a.       0.000238
# 11    P13393,P23255,P35189,P38129,P46677,P50105,P530...  n.a.       0.000711
# 12    P06844,P32494,P32608,P32657,P35177,P38129,P388...  n.a.       0.000711
# 13    P13393,P23255,P35189,P38129,P46677,P50105,P530...  n.a.       0.000711
# 14    P15436,P21951,P22936,P32829,P34220,P38207,P469...  n.a.       0.012664
# 15    P08638,P17106,P25042,P27705,P33400,P34233,P390...  n.a.       0.012664
# 16     P20134,P38236,P40466,P41813,Q03063,Q03125,Q03373  n.a.       0.012664
# 17            P17157,P32561,P43572,P53917,Q06671,Q08649  n.a.       0.012664
# 18            P17157,P32561,P43572,P53917,Q06671,Q08649  n.a.       0.012664
# 19    P25554,P32657,P36106,P36124,P50947,Q03012,Q089...  n.a.       0.012664
# 20            P20134,P38236,P40466,P41813,Q03063,Q03373  n.a.       0.012664
# 21            P22579,P22696,P32561,P40466,P41813,Q08887  n.a.       0.012664
# 22     P00724,P09547,P18480,P18888,P22082,P32591,P38158  n.a.       0.012664
# 23     P00724,P09547,P18480,P18888,P22082,P32591,P38158  n.a.       0.012664
# 24    P07248,P14922,P16649,P31385,P35210,P39001,P391...  n.a.       0.012664
# 25            P20134,P38236,P40466,P41813,Q03063,Q03373  n.a.       0.012664
# 26    P17157,P32561,P38634,P38691,P38742,P39923,P435...  n.a.       0.012664
# 27    P08638,P17106,P25042,P27705,P33400,P34233,P390...  n.a.       0.012664
# 28     P15436,P26793,P46957,P47110,P53942,Q05635,Q12338  n.a.       0.012664
# 29    P15938,P21374,P24384,P28004,P33334,P33411,P409...  n.a.       0.012664
# ...                                                 ...   ...            ...
# 4866                                                NaN  n.a.       0.209341
# 4867                                                NaN  n.a.       0.209341
# 4868                                                NaN  n.a.       0.209341
# 4869                                                NaN  n.a.       0.209341
# 4870                                                NaN  n.a.       0.209341
# 4871                                                NaN  n.a.       0.209341
# 4872                                                NaN  n.a.       0.209341
# 4873                                                NaN  n.a.       0.209341
# 4874                                                NaN  n.a.       0.209341
# 4875                                                NaN  n.a.       0.209341
# 4876                                                NaN  n.a.       0.209341
# 4877                                                NaN  n.a.       0.209341
# 4878                                                NaN  n.a.       0.209341
# 4879                                                NaN  n.a.       0.209341
# 4880                                                NaN  n.a.       0.209341
# 4881                                                NaN  n.a.       0.209341
# 4882                                                NaN  n.a.       0.209341
# 4883                                                NaN  n.a.       0.209341
# 4884                                                NaN  n.a.       0.209341
# 4885                                                NaN  n.a.       0.209341
# 4886                                                NaN  n.a.       0.209341
# 4887                                                NaN  n.a.       0.209341
# 4888                                                NaN  n.a.       0.209341
# 4889                                                NaN  n.a.       0.209341
# 4890                                                NaN  n.a.       0.209341
# 4891                                                NaN  n.a.       0.209341
# 4892                                                NaN  n.a.       0.209341
# 4893                                                NaN  n.a.       0.209341
# 4894                                                NaN  n.a.       0.209341
# 4895                                                NaN  n.a.       0.209341
#
# [4896 rows x 18 columns]
