# %%
import pandas as pd

# %%
fn = r'/Users/dblyon/CloudStation/CPR/Ancient_Proteins_Project/fasta/cl/proteinGroups_LCA.txt'
df = pd.read_csv(fn, sep='\t')

# %%
df[['Majority protein IDs','TaxID_LCA','TaxName_LCA']]
# Out:
#                                    Majority protein IDs  TaxID_LCA  \
# 0                                         A0A888;A0A889     314295
# 1                                                A0A890       9579
# 2                                                A0JN62       9913
# 3     pavi2522_c_1_73;pavi_c_4_1515;gi|480314000|gb|...       1760
# 4                                         A0JT07;A1R3H9       1663
# 5                                         A0JU21;A1R485       1663
# 6                                                A0JUV8     290399
# 7                                         B8HAY9;A0JY64       1663
# 8                           B8HAZ1;A0JY66;A9WNC6;A1R7V5       1268
# 9     Q8NSV7;Q8FS36;Q4JTB8;P61685;gi|535928375|gb|ER...     201174
# 10                                               A0JZ88     290399
# 11                                        B8HD25;A0JZA3       1663
# 12    Q39KI2;Q1BRT3;Q0BJ48;P33167;A4JAM5;A0K3L0;gi|4...      80840
# ...

# %%
df.loc[14, 'Majority protein IDs'].split(';')
# Out:
# ['bcep_c_1_2629',
#  'Q87VP0',
#  'Q4ZN06',
#  'Q4KJ10',
#  'Q48DE6',
#  'pstu_c_1_3721',
#  'ppse_c_3_1010',
#  'pflu1300_c_1_637',
#  'gi|68348432|gb|AAY96038.1|',
#  'gi|399110289|emb|CCH39479.1|',
#  'gi|390981829|gb|AFM31822.1|',
#  'gi|379065140|gb|EHY77883.1|',
#  'gi|359758574|gb|AEV60653.1|',
#  'gi|338803138|gb|AEJ06970.1|',
#  'gi|327482365|gb|AEA85675.1|',
#  'A6SZ07',
#  'Q5E728',
#  'pmir1289_c_1_3683',
#  'pmir_c_1_140',
#  'P17086',
#  'gi|529186887|gb|AGS58647.1|',
#  'gi|404597744|gb|EKA98239.1|',
#  'gi|227161586|gb|EEI46623.1|',
#  'gi|194684975|emb|CAR47185.1|',
#  'B5FBC6',
#  'Q39IW3',
#  'Q2Y9M7',
#  'Q1BYH2',
#  'gi|402248568|gb|AFQ49022.1|',
#  'B4ECC7',
#  'B1JX29',
#  'A0K576',
#  'gi|221724255|gb|ACM27411.1|',
#  'B9J8M3',
#  'Q2K517',
#  'Q1MCV9',
#  'Q133L6',
#  'Q11EW4',
#  'C3MGI5',
#  'B5ZMP0',
#  'B3PXB3',
#  'Q7V3V2',
#  'A2CE01',
#  'B7K912',
#  'gi|145572246|gb|ABP81352.1|']
